# %%
import pandas as pd

# %%
df = pd.read_csv('Dados/TabDesafio.csv')

df
# Out:
#      Questao 1  Questao 2  Questao 3  Questao 4  Questao 5  Questao 6  \
# 0         0.50       0.75       0.55       0.75       0.50       0.50
# 1         0.40       0.70       0.70       1.00       0.45       0.45
# 2         0.30       0.65       0.75       0.80       0.40       0.40
# 3         0.20       0.60       0.70       0.90       0.45       0.40
# 4         0.45       0.45       0.75       0.85       0.50       0.50
# ..         ...        ...        ...        ...        ...        ...
# 119       0.40       0.70       0.70       1.00       0.45       0.45
# 120       0.30       0.65       0.75       0.80       0.40       0.40
# 121       0.20       0.60       0.70       0.90       0.45       0.40
# 122       0.45       0.45       0.75       0.85       0.50       0.50
# 123       0.50       0.75       0.55       0.75       0.50       0.50
#
#      Questao 7  Questao 8  Questao 9  Questao 10  Questao 11  Questao 12  \
# ...

# %%
df.mean()
# Out:
# Questao 1     0.355645
# Questao 2     0.606855
# Questao 3     0.701210
# Questao 4     0.858871
# Questao 5     0.460081
# Questao 6     0.447177
# Questao 7     0.850806
# Questao 8     0.460081
# Questao 9     0.460081
# Questao 10    0.460081
# Questao 11    0.433226
# Questao 12    0.390323
# Questao 13    0.425000
# Questao 14    0.460887
# Questao 15    0.292742
# Questao 16    0.339919
# Questao 17    0.452419
# dtype: float64

# %%
# Calculate the sum of all columns for each row and store in a new 'Total' column
df['Total'] = df.sum(axis=1)

# %%
df
# Out:
#      Questao 1  Questao 2  Questao 3  Questao 4  Questao 5  Questao 6  \
# 0         0.50       0.75       0.55       0.75       0.50       0.50
# 1         0.40       0.70       0.70       1.00       0.45       0.45
# 2         0.30       0.65       0.75       0.80       0.40       0.40
# 3         0.20       0.60       0.70       0.90       0.45       0.40
# 4         0.45       0.45       0.75       0.85       0.50       0.50
# ..         ...        ...        ...        ...        ...        ...
# 119       0.40       0.70       0.70       1.00       0.45       0.45
# 120       0.30       0.65       0.75       0.80       0.40       0.40
# 121       0.20       0.60       0.70       0.90       0.45       0.40
# 122       0.45       0.45       0.75       0.85       0.50       0.50
# 123       0.50       0.75       0.55       0.75       0.50       0.50
#
#      Questao 7  Questao 8  Questao 9  Questao 10  Questao 11  Questao 12  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Questao 1   124 non-null    float64
#  1   Questao 2   124 non-null    float64
#  2   Questao 3   124 non-null    float64
#  3   Questao 4   124 non-null    float64
#  4   Questao 5   124 non-null    float64
#  5   Questao 6   124 non-null    float64
#  6   Questao 7   124 non-null    float64
#  7   Questao 8   124 non-null    float64
#  8   Questao 9   124 non-null    float64
#  9   Questao 10  124 non-null    float64
#  10  Questao 11  124 non-null    float64
#  11  Questao 12  124 non-null    float64
#  12  Questao 13  124 non-null    float64
#  13  Questao 14  124 non-null    float64
#  14  Questao 15  124 non-null    float64
#  15  Questao 16  124 non-null    float64
#  16  Questao 17  124 non-null    float64
#  17  Total       124 non-null    float64
# dtypes: float64(18)
# ...

# %%
df.head()
# Out:
#    Questao 1  Questao 2  Questao 3  Questao 4  Questao 5  Questao 6  \
# 0       0.50       0.75       0.55       0.75       0.50       0.50
# 1       0.40       0.70       0.70       1.00       0.45       0.45
# 2       0.30       0.65       0.75       0.80       0.40       0.40
# 3       0.20       0.60       0.70       0.90       0.45       0.40
# 4       0.45       0.45       0.75       0.85       0.50       0.50
#
#    Questao 7  Questao 8  Questao 9  Questao 10  Questao 11  Questao 12  \
# 0        1.0       0.50       0.50        0.50        0.25        0.15
# 1        1.0       0.45       0.45        0.45        0.46        0.50
# 2        0.9       0.40       0.40        0.40        0.44        0.40
# 3        0.8       0.50       0.45        0.50        0.45        0.45
# 4        0.7       0.45       0.50        0.45        0.50        0.40
#
#    Questao 13  Questao 14  Questao 15  Questao 16  Questao 17  Total
# ...

# %%
df.describe()
# Out:
#         Questao 1   Questao 2   Questao 3   Questao 4   Questao 5   Questao 6  \
# count  124.000000  124.000000  124.000000  124.000000  124.000000  124.000000
# mean     0.355645    0.606855    0.701210    0.858871    0.460081    0.447177
# std      0.112114    0.104829    0.066706    0.075182    0.037709    0.046549
# min      0.200000    0.450000    0.550000    0.750000    0.400000    0.400000
# 25%      0.200000    0.450000    0.700000    0.800000    0.450000    0.400000
# 50%      0.400000    0.600000    0.700000    0.850000    0.450000    0.450000
# 75%      0.450000    0.700000    0.750000    0.900000    0.500000    0.500000
# max      0.500000    0.750000    0.750000    1.000000    0.500000    0.500000
#
#         Questao 7   Questao 8   Questao 9  Questao 10  Questao 11  Questao 12  \
# count  124.000000  124.000000  124.000000  124.000000  124.000000  124.000000
# mean     0.850806    0.460081    0.460081    0.460081    0.433226    0.390323
# ...
